# %%
import numpy as np
import pandas as pd

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data_route = '/content/gdrive/MyDrive/final_data.csv'

# %%
accident_data = pd.read_csv(data_route, encoding='UTF-8')
accident_data
# Out:
#             report_time report_time_simple               발생장소  사고원인 지점코드   지점  \
# 0       2010-01-01 5:40    2010-01-01 5:00   전라남도 진도군 진도읍 남동리  일반조난   진도  175
# 1       2010-01-01 5:40    2010-01-01 5:00   전라남도 진도군 진도읍 남동리  일반조난   진도  175
# 2       2010-01-01 7:14    2010-01-01 7:00   경상북도 문경시 문경읍 상초리  일반조난   문경  273
# 3       2010-01-01 7:31    2010-01-01 7:00   충청북도 청주시 흥덕구 산남동  개인질환   청주  131
# 4       2010-01-01 7:47    2010-01-01 7:00      강원도 태백시 혈동 혈동  산악기타   태백  216
# ...                 ...                ...                ...   ...  ...  ...
# 86123   2021-12-31 5:14    2021-12-31 5:00   대구광역시 남구 봉덕동 봉덕동  일반조난   대구  143
# 86124  2021-12-31 10:22   2021-12-31 10:00   광주광역시 서구 화정동 화정동  기타산악   광주  156
# 86125  2021-12-31 14:32   2021-12-31 14:00  서울특별시 은평구 진관동 진관동  실족추락   서울  108
# 86126  2021-12-31 14:58   2021-12-31 14:00  서울특별시 은평구 진관동 진관동  실족추락   서울  108
# 86127  2021-12-31 18:16   2021-12-31 18:00   대구광역시 동구 숙천동 숙천동  일반조난   대구  143
#
# ...

# %%
# 17년도 전 데이터와 후 데이터에서 안겹치는 사고원인 행 삭제
accident_data = accident_data[accident_data['사고원인'] != '탈진·탈수']
accident_data = accident_data[accident_data['사고원인'] != '저체온증']
accident_data = accident_data[accident_data['사고원인'] != '자살기도']
accident_data = accident_data[accident_data['사고원인'] != '낙석·낙빙']
accident_data = accident_data[accident_data['사고원인'] != '고온환경질환']
accident_data = accident_data[accident_data['사고원인'] != '야생식물 섭취 중독']
accident_data = accident_data[accident_data['사고원인'] != '암벽등반반']

accident_data
# Out:
#             report_time report_time_simple               발생장소  사고원인 지점코드   지점  \
# 0       2010-01-01 5:40    2010-01-01 5:00   전라남도 진도군 진도읍 남동리  일반조난   진도  175
# 1       2010-01-01 5:40    2010-01-01 5:00   전라남도 진도군 진도읍 남동리  일반조난   진도  175
# 2       2010-01-01 7:14    2010-01-01 7:00   경상북도 문경시 문경읍 상초리  일반조난   문경  273
# 3       2010-01-01 7:31    2010-01-01 7:00   충청북도 청주시 흥덕구 산남동  개인질환   청주  131
# 4       2010-01-01 7:47    2010-01-01 7:00      강원도 태백시 혈동 혈동  산악기타   태백  216
# ...                 ...                ...                ...   ...  ...  ...
# 86123   2021-12-31 5:14    2021-12-31 5:00   대구광역시 남구 봉덕동 봉덕동  일반조난   대구  143
# 86124  2021-12-31 10:22   2021-12-31 10:00   광주광역시 서구 화정동 화정동  기타산악   광주  156
# 86125  2021-12-31 14:32   2021-12-31 14:00  서울특별시 은평구 진관동 진관동  실족추락   서울  108
# 86126  2021-12-31 14:58   2021-12-31 14:00  서울특별시 은평구 진관동 진관동  실족추락   서울  108
# 86127  2021-12-31 18:16   2021-12-31 18:00   대구광역시 동구 숙천동 숙천동  일반조난   대구  143
#
# ...

# %%
accident_data.to_csv('/content/gdrive/MyDrive/final_data_컬럼통합.csv', index=False)
